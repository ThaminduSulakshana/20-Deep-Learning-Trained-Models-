# %%
BASE_DIR = '/content/drive/MyDrive/datasets/Flicker8k'
WORKING_DIR = '/content/drive/MyDrive/datasets/Flicker8k'

# %%
import numpy as np
import pandas as pd

import os
for dirname, _, filenames in os.walk('/content/drive/MyDrive/datasets/Flicker8k'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/MyDrive/datasets/Flicker8k/images/3211577298_14296db6fd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/394563330_68b566368c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3319586526_3994e9cd58.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1475046848_831245fc64.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3701291852_373ea46bb6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2539933563_17ff0758c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2503629305_055e9ec4b1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1663751778_90501966f0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3209620285_edfc479392.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1473250020_dc829a090f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3186073578_6e115f45f5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2995461857_dd26188dcf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2913207978_9e9624e249.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2655647656_ee450446ed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3259002340_707ce96858.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3651476768_2bae721a6b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/268654674_d29e00b3d0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3672105509_53b13b2ed4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3691622437_f13644273c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3343197133_9256848fa9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2787868417_810985234d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2633722629_5eeb649c09.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3170897628_3054087f8c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2833431496_09d999db4d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1425069590_570cc7c2d8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/263850317_5bb3a18a08.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1689658980_0074d81d28.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3403797144_53e49412ec.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2509824208_247aca3ea3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3707077198_efd6aa808d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/408573233_1fff966798.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3634032601_2236676cdd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/237953705_cfe6999307.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2479553749_f7ac031940.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2715337869_e4fe36db50.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/457631171_12b1aee828.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3470951932_27ed74eb0b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2290330500_e7bdaa58e1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/469259974_bb03c15c42.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/270864951_1737ae5479.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2937942758_712be5c610.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3643684616_9d2be87a5a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2837640996_0183db8d93.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3048380686_732db55281.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/236476706_175081ce18.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2564663851_3a9832e4fc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/448252603_7d928c900e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/872135364_8c1e47d163.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3240558825_cd859d6230.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/640506101_ae1145b6d1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3403370354_5d266873b4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1235681222_819231767a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2204550058_2707d92338.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2647593678_1fa3bb516c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1119015538_e8e796281e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3118534315_cc03e5ddab.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2900048238_74bd69d87d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2066241589_b80e9f676c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3608849440_e7d2bed29f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3415003392_139c0f3586.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3479423813_517e93a43a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/667626_18933d713e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2094810449_f8df9dcdf7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2456907314_49bc4591c4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2944193661_7b255af9cc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3134644844_493eec6cdc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2955985301_e4139bc772.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/239807547_4923efc821.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3116985493_04b1dc3345.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3580375310_46ec3e476c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3429142249_d09a32e291.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2822891602_ff61df2ece.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2831314869_5025300133.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3616808182_fb4eaec778.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3030566410_393c36a6c5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2594459477_8ca0121a9a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/416992999_654a99a903.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2876993733_cb26107d18.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3456579559_b5c8927938.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2481490320_7978c76271.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3346289227_198fced308.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3396036947_0af6c3aab7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3360876049_9047edeab9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/900144365_03cd1899e3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3281611946_f42deed2e1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1118557877_736f339752.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/489551372_b19a6ad0ed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2600386812_8790879d9a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/471402959_0b187560df.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3498997518_c2b16f0a0e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3665169936_01ae94c9fd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3745451546_fc8ec70cbd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/539493423_9d7d1b77fa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3269895626_7b253c82ed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/897621891_efb1e00d1d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3349968447_b5d4a477b2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3534824784_7133119316.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2469620360_6c620c6f35.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3532205154_5674b628ea.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/279550225_d64d56158a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3498327617_d2e3db3ee3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2344875609_8e172d682b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2521770311_3086ca90de.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3027850131_a7772e0ba0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2402793046_3385554e81.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/482047956_9a29e9cee6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2049051050_20359a434a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/483039719_75181b2726.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2247889670_413db8094b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2760716468_b541e9fd0f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2611651553_61f859837e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3495453699_1c9faedf3c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2754898893_95239c1f19.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2460799229_ce45a1d940.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3490186050_4cb4193d4d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/285306009_f6ddabe687.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3544803461_a418ca611e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3640329164_20cb245fd5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1176580356_9810d877bf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2932498509_27cb0038ec.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2263655670_517890f5b7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3119887391_212f379797.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3487015378_2e90a79f4b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1874617189_e85d3f4326.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2913818905_8e4d9aa82a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3259222690_69737f2a6e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2714878018_1593c38d69.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/502115726_927dd684d3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2880051254_e0ca96b6be.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3159995270_17334ccb5b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3616771728_2c16bf8d85.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3364160101_c5e6c52b25.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2212472643_80238475b5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1778020185_1d44c04dae.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/33108590_d685bfe51c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3532098999_4e07a0a17e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3341077091_7ca0833373.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3088399255_1bd9a6aa04.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/875731481_a5a0a09934.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2842865689_e37256d9ce.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2873648844_8efc7d78f1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/543291644_64539956e9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2456615908_59cdac6605.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/860928274_744d14f198.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/765091078_a8a11c6f9e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/221973402_ecb1cd51f1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2921094201_2ed70a7963.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2220175999_081aa9cce8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3372215826_b3e6403b2e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2587818583_4aa8e7b174.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3632047678_f202609e50.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3330102093_1d6e35e78d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2318659263_c24005a5cb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3594566537_55bd712fdb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2518094853_dfce24ce8c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2447289477_e888df561d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3330935489_9cb67ca36b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2855667597_bf6ceaef8e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3040051410_6205682ba3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/260231029_966e2f1727.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3609027309_af75f773d9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2885387575_9127ea10f1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2789937754_5d1fa62e95.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3571675421_7e07ac07c5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3019923691_3b3c5a4766.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/256292144_b53aadae27.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2255266906_8222af18b9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1479857177_9d4a6f38fd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3476381830_3751dd9339.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2715035273_8fc8b1291c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2902661518_1513be3ea6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/511844627_0ec78e01e9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3550763985_800cfee7e4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2512876666_9da03f9589.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2195887578_3ba2f29b48.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2865409854_afedf98860.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3425662680_41c7c50e8d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2307451605_22e9c06530.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3472364264_dbde5a8d0a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3534046564_4f8546e364.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2183967273_d182e18cf6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3143155555_32b6d24f34.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3628994466_a12065d29b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3315110972_1090d11728.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3111482098_11c0f4f309.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3716244806_97d5a1fb61.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3027365101_3818be6e16.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3500342526_393c739e2f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1355935187_2c99648138.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2828583747_8cfb7217af.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/333973142_abcd151002.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2306674172_dc07c7f847.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2551344688_17a12a6948.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2084157130_f288e492e4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2891961886_b7a2f0b0fd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2120411340_104eb610b1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/501699433_f8df386cf9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2493974889_50ae29f1e1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2836360729_6500249fe6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3316046339_8e504be038.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3716277216_c04002be81.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/492493570_c27237a396.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3534183988_3763593dfb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3489774350_a94e6c7bfc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/343073813_df822aceac.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3186556417_b2d6921a20.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3546891929_f31a99cd0d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/140377584_12bdbdf2f8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3431194126_ca78f5fde6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2945036454_280fa5b29f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1433397131_8634fa6664.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3330333217_1a69497a74.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2764178773_d63b502812.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2960033435_c20cc7399a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3393152604_27bd1037f2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3166969425_b5ace2f9c2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2244171992_a4beb04d8e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1809758121_96026913bb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3256456935_664a7a5bba.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/296873864_4de75de261 (1).jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1394620454_bf708cc501.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1956678973_223cb1b847.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2088460083_42ee8a595a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1191338263_a4fa073154.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/258476074_f28f4a1ae6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3694093650_547259731e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1164765687_7aca07bbe7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3320756943_9d004f9824.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2447972568_1e9b287691.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/522486784_978021d537.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2234910971_80e0325918.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2034553054_b00c166895.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2482629385_f370b290d1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1459250022_bf1eddad11.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2662262499_3cdf49cedd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3425756814_13909354d4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1682079482_9a72fa57fa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3297323827_f582356478.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3375014075_157388f8a9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1463638541_c02cfa04dc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/447722389_4b51b7e13d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2780105274_52360c4cca.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3485816074_363cab4bff.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/836828001_af98d16256.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3516653997_98ec551a67.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3621177753_1718c30ea0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/523692399_d2e261a302.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/542405691_0594b1ce72.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1472249944_d887c3aeda.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3231880001_193a579b97.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2571096893_694ce79768.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3205214191_29b42b9b09.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3375920709_ef7370fa09.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/415657941_454d370721.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2232518012_8cb0bbc43b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/970641406_9a20ee636a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2847859796_4d9cb0d31f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/391324644_d23fdf06cb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2778290592_1910bb0431.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/304408047_98bab3ea64.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/260162669_c79a900afb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3697456750_460aea7252.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2868776402_aef437e493.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2741051940_89fb6b2cee.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3295452057_0c987f895f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/241346971_c100650320.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1428681303_04213524e3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2353088412_5e5804c6f5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/219070971_ae43410b9e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2885382946_f541ea5722.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1461653394_8ab96aae63.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3415578043_03d33e6efd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1884727806_d84f209868.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2565618804_8d7ed87389.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2601008162_f00eeb5c14.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2892989340_bb7e0e5548.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1417295167_5299df6db8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3189307452_aebc12380b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3653837067_94050699ec.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2043427251_83b746da8e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1569562856_eedb5a0a1f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2797438951_88a3ed7541.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3613375729_d0b3c41556.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/275516348_cbccebc125.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/54723805_bcf7af3f16.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3099264059_21653e2536.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3454315016_f1e30d4676.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/537479916_c033897fac.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3415228562_4efa9c9b70.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2393264648_a280744f97.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/473988700_570422001b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3266261886_36e1323d2f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/496380034_d22aeeedb3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/384465370_9918873f9a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3064383768_f6838f57da.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3321334180_8f764e0e0f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3085973779_29f44fbdaa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2472634822_7d5d2858c0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/427683329_95d510a087.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2393410666_b8c20fff61.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3295671644_0e10891b6d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2735979477_eef7c680f9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3269380710_9161b0bd00.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3648097366_706c8a57a1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2866529477_7e0c053ebc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2888386138_578d21033a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1001773457_577c3a7d70.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1388346434_524d0b6dfa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3043266735_904dda6ded.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1476241331_2f43b67aed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/432167214_c17fcc1a2d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/394161692_2576920777.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1363924449_487f0733df.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/282116218_7fd7583d6e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2969380952_9f1eb7f93b (1).jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3425851292_de92a072ee.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3196100539_102fe877b3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2558312618_13d362df66.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/367925122_335ed279a8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3058439373_9276a4702a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2881087519_ca0aa79b2b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2266142543_b2de18c081.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1465666502_de289b3b9c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3043904009_3b5e0412cd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2437266971_b91a8f9a00.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1579198375_84b18e003a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1405221276_21634dcd58.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3244171699_ace4b5d999.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2215136723_960edfea49.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2219805677_7b7cc188c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/374567836_3ae12ecffb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3516299821_8f0375d221.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3171066023_ec60ba30f3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2534502836_7a75305655.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/457875937_982588d918.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2733659177_d74a00995b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3457455611_94ee93929f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/242109387_e497277e07.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3718892835_a3e74a3417.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/381514859_b40418d9c3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3701249979_8bc757e171.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/263854883_0f320c1562.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3697378565_7060d9281a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3424927725_c4d1fcfac3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3339263085_6db9fd0981.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2670637584_d96efb8afa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/55470226_52ff517151.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2405599120_ec5f32af6f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3392851587_a638ff25e2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/543326592_70bd4d8602.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3028095878_07341efc9c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/426065353_e9a604a01f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3356494271_6103d0b556.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/160585932_fa6339f248.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2839532455_36a7dc4758.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2243904502_2d265fed80.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3358682439_be4b83544c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3088572348_264c47f78c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3494345896_dd6b32cfa3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3393446245_37dd3f3b59.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/293879742_5fe0ffd894.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3425071001_e7c9809ef2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2681215810_00b0642f7b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2260649048_ae45d17e68.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/495014499_8fd065cfd9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2810333931_47fd8dd340.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/493507605_48fe8e3739.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2902486045_6298eb22ef.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1434005938_ad75c8598c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3576060775_d9121519cc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2956413620_d59de03a06.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/771048251_602e5e8f45.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/823697339_aadbeef495.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1443807993_aebfb2784a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3626642428_3396568c3c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2602679255_785b851b46.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3218889785_86cb64014f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/782017931_75d92bb7a4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2727051596_be65bfb3d3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/289616152_012a9f16c6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3366904106_e996320d20.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/260392825_ea61660633.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2656749876_e32495bd8c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2696866120_254a0345bc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2140305708_591d10b54d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3111402233_6285bcba7a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3699763582_f28c5130dd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2664103423_c539f61016.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2987195421_e830c59fb6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3708244207_0d3a2b2f92.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2453971388_76616b6a82.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/508958120_afe274f726.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/530888330_a18343e38d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/271660510_dd4ba34b35.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/222759342_98294380fc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2887744223_029f2fd5fe.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3275527950_41aca690a1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2268601066_b018b124fd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2891240104_6755281868.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/515702827_be3c6ce857.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2633082074_32c85f532c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2943384009_c8cf749181.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1342780478_bacc32344d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3056530884_27766059bc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1464120327_d90279ca3a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2194495372_bdac7d9e71.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/112243673_fd68255217.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2508313118_524e93d48c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2384147448_c1869070d3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2249865945_f432c8e5da.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2148695079_9ae6a9b1c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/451081733_40218cec31.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2762702644_2aa3bf9680.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/124195430_d14028660f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/533483374_86c5d4c13e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/812196663_0c969970b5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/368212336_bc19b0bb72.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2826647354_650ff5eb03.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2825483885_3f7c54db3e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2457052334_b5a1d99048.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3599442049_e448c7c9b2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3197247245_9c93b60b8a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3315353266_70f0bbb1c3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3477672764_7f07657a26.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3046286572_d2050ab0d9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/527272653_8a5bd818e5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2516317118_10ae66b87a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2198511848_311d8a8c2f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3105623068_392b767a7b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/463978865_c87c6ca84c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3138562460_44227a35cf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3649384501_f1e06c58c0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/502671104_b2114246c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/296873864_4de75de261.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/940973925_a2e6d7951c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2374247382_023a86b9ca.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/325576658_59f68bdbd6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3650111717_346804ec2f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/245895500_a4eb97af02.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2938072630_d641b63e4d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1478268555_7e301fc510.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2836325261_a3bf5c59be.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2057306459_2f52ce648e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2672588619_3849930e99.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3347500603_13670ee6bf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/460935487_75b2da7854.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2271671533_7538ccd556.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1662261486_db967930de.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2782480767_064c95eff2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3412450683_7da035f2de.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2242863004_3a9f82a31f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2940366012_1ef8ab334e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2355819665_39021ff642.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3636055584_65a60426f8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3041645937_ff7591d134.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1026685415_0431cbf574.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3163477256_073605e06e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3251906388_c09d44340e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3655773435_c234e94820.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/241345942_ea76966542.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3421129418_088af794f7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/269986132_91b71e8aaa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1160034462_16b38174fe.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2768662025_44001fe5d1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1459032057_97e73ed6ab.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2393911878_68afe6e6c1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2942133798_e57c862a90.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/381976882_0063d16d88.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2261257940_449b6e6c91.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2100909581_b7dde5b704.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3453019315_cfd5c10dae.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3374759363_d6f7a0df41.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2701042060_92508ea8fa.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3258394043_a0b6a94dce.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2672354635_3a03f76486.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2969380952_9f1eb7f93b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3148193539_de9dd48fc8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3487979741_5f244c0c4b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2853811730_fbb8ab0878.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2368266191_87d77750f1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3293596075_973b0bfd08.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2380464803_a64f05bfa9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2603792708_18a97bac97.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/412203580_2c7278909c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2713897716_c8cd610360.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2650485780_29d89268d7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2854234756_8c0e472f51.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2842609837_b3a0b383f7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2214132302_80064fd79d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/458004873_f084c47a88.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3116011063_f4071ccce6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/375384566_254c2362d4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3461106572_920c8c0112.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3126681108_f88128699c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2533414541_362bf043bb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3738685861_8dfff28760.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3088074124_481139dc92.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2053006423_6adf69ca67.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/822836318_21544f0f78.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2510029990_7014f907cb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1468103286_96a6e07029.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2885111681_dc328ecfff.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3520321387_710ab74cda.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3263497678_8bb688ca01.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2135360514_7dcb9ed796.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2493469969_11b6190615.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2196050115_e236d91f52.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3332467180_d72f9b067d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/109260216_85b0be5378.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3191982761_88793192ed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3227594168_3351722aae.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3409947123_a8d07edecf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3108197858_441ff38565.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/635444010_bd81c89ab7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/871290666_4877e128c0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2894229082_ddc395f138.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3341489212_a879e1544a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2229179070_dc8ea8582e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/874665322_9ad05c4065.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1255504166_f2437febcb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/873633312_a756d8b381.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2923825744_ca125353f0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2673564214_3a9598804f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3559374748_f18c7caa55.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3671950830_b570bac1b9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3534668485_6887629ff0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2465497494_43d74df57c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3730011701_5352e02286.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/143680442_2f03f76944.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2887614578_ed7ba21775.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3170802797_3c851bb475.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3767841911_6678052eb6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3211453055_05cbfe37cd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3442540072_b22ca2410f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3580082200_ea10bf2f68.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3502563726_30d1ce29c8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3457460673_800d7f7dd9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2160266952_a2ab39191b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2074244690_82e30ff44b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3221036999_3f7b152d8a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3073535022_4af81f360c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2856923934_6eb8832c9a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3243588540_b418ac7eda.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3572942419_16ebdc3d46.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3419238351_ac18b440c0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2064790732_219e52e19c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3705976184_53ae07e898.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2861932486_52befd8592.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2355880294_8f78a6fea6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3670075789_92ea9a183a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3298175192_bbef524ddc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3523819210_99782628fc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2648165716_02e2e74fd6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2364394224_c17b09e035.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/397982550_cf9f5cdb74.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3146937399_8c046b7b1a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3522000960_47415c3890.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3185695861_86152b2755.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/210686241_b8e069fff3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3279988814_d3693dcb6c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2480832276_fa55480ecb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2557129157_074a5a3128.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3475092236_cf45d383c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2938875913_0ed920a6be.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/311619377_2ba3b36675.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3086507638_d8a2cd0ac3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2300229745_af7a20c959.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/506367606_7cca2bba9b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3349451628_4249a21c8f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3662963630_8f097e38d4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2981372647_2061278c60.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2607130765_97833d6ce1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2218743570_9d6614c51c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2616284322_b13e7c344e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3454621502_73af6742fb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1994416869_4dd769a806.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2877637572_641cd29901.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3565021218_d2bc1aa644.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2115631346_9585a479b0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3398745929_8cd3bbb8a8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3423249426_02bedf9260.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3203707977_cc9448fecb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3724581378_41049da264.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3701878677_8f2c26227b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3475005101_6f6e437459.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1356796100_b265479721.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2968182121_b3b491df85.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3410902181_b2a3c6eec9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2461616306_3ee7ac1b4b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1022454332_6af2c1449a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2942094037_f6b36fd3db.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3294964868_16f4f9fa9d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1149179852_acad4d7300.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3577235421_69e4efb8d1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3442138291_3e75f4bdb8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/268365231_a0acecdc45.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3550276904_19de3561c5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3255482333_5bcee79f7e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3443460885_46115463b4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2744600462_5804577296.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/247691240_3881777ab8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3113769557_9edbb8275c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3517362674_0f5296de19.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3088322308_b0c940b3a3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3207676216_48478bce97.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/292780636_72e1968949.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/417577408_eb571658c1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/709373049_15b8b6457a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3545427060_c16a8b7dfd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/365759754_6cf7068c9a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2384401298_e389c01abc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3396251819_1efa69310f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2935986346_29df6cf692.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/582788646_dc40748639.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/124972799_de706b6d0b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3237760601_5334f3f3b5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3123770450_cedc16d162.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2125454445_5c5c4bf906.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3016200560_5bf8a70797.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1167908324_8caab45e15.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3214579977_fa9fb006a6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2085557551_7a88d01d4e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3166366760_e43cf66eda.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2623560640_0445c9a138.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3606355203_1260f43ec0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3665549027_d7fb05d157.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3009018821_ba47396e24.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3301021288_95935b7a74.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3165750962_e2e3843679.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2089350172_dc2cf9fcf6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3484365373_98d5304935.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3589368949_0866846949.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3596131692_91b8a05606.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3027399066_ca85495775.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2914206497_5e36ac6324.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3220009216_10f088185e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2116316160_d5fa7abdc3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3648160673_0c783236a6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3453313865_1ebff5393c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/527288854_f26127b770.jpg
# ...
# /content/drive/MyDrive/datasets/Flicker8k/images/3294179574_4f67e67d6f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3326376344_3306bf439e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1785138090_76a56aaabc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/477254932_56b48d775d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3185409663_95f6b958d8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3618908551_7fd2de5710.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/359082432_c1fd5aa2d6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3694064560_467683205b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2142232919_c857a09dd7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3436063693_15c8d377a2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2676764246_c58205a365.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2853407781_c9fea8eef4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2868668723_0741222b23.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3722507770_0d6cb7420e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2896298341_92d718366a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3397220683_4aca010f86.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1468389504_c724bdcad0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2230067846_74046b89d3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/311196733_03966b4836.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3273091032_98f724b36b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/410042380_517ccee020.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3524436870_7670df68e8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1732217138_aa0199ef87.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/510197538_0a11b94460.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3609999845_faf5d2fe74.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1895768965_43cd9d164f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2497420371_74788d7ba1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2705793985_007cc703fb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2593695271_4d9cc9bd6f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/241347760_d44c8d3a01.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/701816897_221bbe761a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3547600292_6f8aac7f2e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1801063894_60bce29e19.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/493542985_c85ad29ebe.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2419591925_1038c6c570.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2144050118_3e7d2e05b1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3457784061_8f77f43a9c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3159424456_f316bdc1d5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3562302012_0cbcd01ff9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3038760935_9a713510eb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1294578091_2ad02fea91.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/436015762_8d0bae90c3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2714220101_c31db50b10.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/782401952_5bc5d3413a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2672445419_251ce9419a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2226440063_c085b30558.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3188036349_8e4e2d6ca8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2813033949_e19fa08805.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3134586018_ae03ba20a0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3046259614_614394e024.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/453756106_711c20471a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1491192153_7c395991e5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3349307529_c1a516b9dc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/444803340_fdcaab86f9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/490044494_d2d546be8d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2101457132_69c950bc45.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3468275336_61936db92d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2976155358_b4dd4407cf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/716597900_b72c58362c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3416246113_1745559b6b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3550253365_27d4c303cf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/523327429_af093fc7cf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/321229104_3cbaf0f51c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/345684566_235e8dfcc1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2973638173_0dc21fd443.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3317333893_9d0faa8d30.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2704362232_7d84503433.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3527682660_c5e9fa644a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2728486640_cc2a31d2b0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2550109269_bc4262bd27.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3540515072_8c951b738b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2646540383_343e1ec9a4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2857558098_98e9249284.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/84713990_d3f3cef78b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3556598205_86c180769d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/475778645_65b7343c47.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2180356743_b3a3c9a7f6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3249891874_6a090ef097.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3497238310_2abde3965d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/933118213_b35b0b62a7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/507758961_e63ca126cc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3619416477_9d18580a14.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2087640654_1a84577a44.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/255330891_86d65dfdbf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3667404919_b273df57e4.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/130211457_be3f6b335d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3688839836_ba5e4c24fc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2683985894_167d267dcb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3404012438_9baf8dcbaf.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2709275718_73fcf08c23.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2423292784_166ee54e0b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2328104318_5a43ca170c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2079152458_40712c3b40.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3087095548_6df7c2a8ed.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2975253472_0f0c2dea70.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3138504165_c7ae396294.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2398605966_1d0c9e6a20.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1655781989_b15ab4cbff.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/897406883_f09f673d94.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/134724228_30408cd77f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3465396606_5ba1574128.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/234241682_51d9fabb27.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3439382048_d2e23b2b4c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/380527679_574749123d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3670918456_68631d362a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3122938209_2b2c6c1fab.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3616846215_d61881b60f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3289817083_4e78e1c05a.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1884065356_c6c34b4568.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/531152619_6db02a7ed9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3252457866_b86614064c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3269087421_1d489abeae.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2438085746_588dce8724.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3336682980_1082a66878.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3710073758_ac2b217f29.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/240583223_e26e17ee96.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3339586622_a7676b30e1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2095078658_c14ba89bc2.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3025495499_b15797b452.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3452411712_5b42d2a1b5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3661072592_2e693cd5a0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3341477531_4e37450f35.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3041689520_c481bdb20e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3442242092_e579538d82.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/452419961_6d42ab7000.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1786425974_c7c5ad6aa1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2463067409_78188c584c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3151365121_e2a685a666.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1206506157_c7956accd5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2173061319_1f267765dc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2508249781_36e9282423.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1075881101_d55c46bece.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2676015068_690b0fb2cd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2424398046_1a55c71376.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3467510271_0f57e52768.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2439813616_c9ac54cc9f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/199809190_e3f6bbe2bc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2472980433_210ec62874.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/300594071_3450444752.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2838125339_3dd314e315.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3639845565_be547c38ba.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3356369156_074750c6cc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3636543173_15f56515e5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3245250964_9d3e37111e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1718184338_5968d88edb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2830309113_c79d7be554.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2194494220_bb2178832c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2187904131_96ea83b9b5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/246094557_e174a5914f.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/354999632_915ea81e53.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1801663973_5ad393caeb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3635911776_dbc2763f2c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3262386960_14f5d857db.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3021318991_fa28e3bca7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3724759125_2dc0e1f4a3.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2718495608_d8533e3ac5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3364861247_d590fa170d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3620492762_7f6a9b4746.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3085667767_66041b202e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2339946012_06bd480ab8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3353400143_8b9543f7dc.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2992808092_5f677085b7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3034585889_388d6ffcc0.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/357191373_a1cb5696e8.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3439560988_f001f96fc9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1332208215_fa824f6659.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3291255271_a185eba408.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/444872454_9f51e07f88.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1527513023_3d8152b379.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3621717946_d96f8a6012.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3146630574_05d9ebbed1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3605100550_01214a1224.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3499720588_c32590108e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3294202771_e8ee78a439.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/53043785_c468d6f931.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3432586199_e50b0d6cb7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2319197581_94f807b204.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/540604040_bec822c144.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2265100168_175f8218af.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2730938963_c4ed3e2258.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3677734351_63d60844cb.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2660480624_45f88b3022.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3591170729_406fdb74e5.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2687672606_275169c35d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3613323772_d15cef66d1.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1000268201_693b08cb0e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3123463486_f5b36a3624.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1129704496_4a61441f2c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3518675890_2f65e23ff9.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1501985304_8c50093004.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2278776373_fe499a93be.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3178371973_60c6b8f110.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3333017828_b930b9d41b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3587077732_0933f1677b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1384292980_4022a7520c.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3539840291_1c3eed701d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3048461682_e89f81b1c7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/479807115_3a484fb18b.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3647750811_395fbd397e.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3482859574_3908de3427.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/333031366_a0828c540d.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2068465241_3bcabacfd7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2147199188_d2d70b88ec.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3724113279_99b6e5bf41.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/1306145560_1e37081b91.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2395967330_7e6ea404f6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3708172446_4034ddc5f6.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/58363930_0544844edd.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3239480519_22540b5016.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/2742426734_291df6da08.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/571507143_be346225b7.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/3644941648_012ec87848.jpg
# /content/drive/MyDrive/datasets/Flicker8k/images/235074044_c1358888ed.jpg

# %%
import os
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import efficientnet
from tensorflow.keras.layers import TextVectorization


seed = 52
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
IMAGE_PATH ='/content/drive/MyDrive/datasets/Flicker8k/images'

# %%
# Desired image dimensions
IMAGE_SIZE = (224, 224)

# Vocabulary size
VOCAB_SIZE = 10000

# Fixed length allowed for any sequence
SEQ_LENGTH = 25

# Dimension for the image embeddings and token embeddings
EMBED_DIM = 512

# Per-layer units in the feed-forward network
FF_DIM = 512

# Other training parameters which we will during the traing
BATCH_SIZE = 32
EPOCHS = 30
AUTOTUNE = tf.data.AUTOTUNE

# %%
def load_captions_data(filename):

    with open(filename) as caption_file:
        caption_data = caption_file.readlines()
        caption_mapping = {}
        text_data = []
        images_to_skip = set()

        for line in caption_data:
            line = line.rstrip("\n")

            img_name, caption = line.split(",",1)
            #remove "" from caption
            caption = caption.strip().strip('"')



            # Each image is repeated five times for the five different captions.
            img_name = os.path.join(IMAGE_PATH, img_name.strip())

            # will remove caption that are either too short to too long
            tokens = caption.strip().split()

            if len(tokens) < 5 or len(tokens) > SEQ_LENGTH:
                images_to_skip.add(img_name)
                continue

            if img_name.endswith("jpg") and img_name not in images_to_skip:

                caption = "<start> " + caption.strip() + " <end>"
                text_data.append(caption)

                if img_name in caption_mapping:
                    caption_mapping[img_name].append(caption)
                else:
                    caption_mapping[img_name] = [caption]

        for img_name in images_to_skip:
            if img_name in caption_mapping:
                del caption_mapping[img_name]

        return caption_mapping, text_data

# %%
load_caption=load_captions_data('/content/drive/MyDrive/datasets/Flicker8k/captions.txt')
type(load_caption)
#load_caption[:1]
# Out:
# tuple

# %%
def train_val_split(caption_data, train_size=0.9, shuffle=True):

    # 1. Get the list of all image names
    all_images = list(caption_data.keys())

    # 2. Shuffle if necessary
    if shuffle:
        np.random.shuffle(all_images)

    # 3. Split into training and validation sets
    train_size = int(len(caption_data) * train_size)

    training_data = {
        img_name: caption_data[img_name] for img_name in all_images[:train_size]
    }
    validation_data = {
        img_name: caption_data[img_name] for img_name in all_images[train_size:]
    }

    # 4. Return the splits
    return training_data, validation_data

# %%
# Load the dataset
captions_mapping, text_data = load_captions_data("/content/drive/MyDrive/datasets/Flicker8k/captions.txt")

# Split the dataset into training and validation sets
train_data, valid_data = train_val_split(captions_mapping)
print("Number of training samples: ", len(train_data))
print("Number of validation samples: ", len(valid_data))
# Out:
# Number of training samples:  6879
# Number of validation samples:  765

# %%
def custom_standardization(input_string):
    lowercase = tf.strings.lower(input_string)
    return tf.strings.regex_replace(lowercase, "[%s]" % re.escape(strip_chars), "")

#Remove punchuation
strip_chars = "!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"
strip_chars = strip_chars.replace("<", "")
strip_chars = strip_chars.replace(">", "")

vectorization = TextVectorization(
    max_tokens=VOCAB_SIZE,
    output_mode="int",
    output_sequence_length=SEQ_LENGTH,
    standardize=custom_standardization,
)
vectorization.adapt(text_data)

# Data augmentation for image data
image_augmentation = keras.Sequential(
    [
        layers.RandomFlip("horizontal"),
        layers.RandomRotation(0.2),
        layers.RandomContrast(0.3),
    ]
)

# %%
def decode_and_resize(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_jpeg(img, channels=3)
    img = tf.image.resize(img, IMAGE_SIZE)
    img = tf.image.convert_image_dtype(img, tf.float32)
    return img


def process_input(img_path, captions):
    return decode_and_resize(img_path), vectorization(captions)


def make_dataset(images, captions):
    dataset = tf.data.Dataset.from_tensor_slices((images, captions))
    dataset = dataset.shuffle(BATCH_SIZE * 8)
    dataset = dataset.map(process_input, num_parallel_calls=AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE).prefetch(AUTOTUNE)

    return dataset


# Pass the list of images and the list of corresponding captions
train_dataset = make_dataset(list(train_data.keys()), list(train_data.values()))

valid_dataset = make_dataset(list(valid_data.keys()), list(valid_data.values()))

# %%
train_dataset,valid_dataset
# Out:
# (<_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 25), dtype=tf.int64, name=None))>,
#  <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None, None, 25), dtype=tf.int64, name=None))>)

# %%
def get_cnn_model():
    base_model = efficientnet.EfficientNetB0(
        input_shape=(*IMAGE_SIZE, 3), include_top=False, weights="imagenet",
    )
    # We freeze our feature extractor
    base_model.trainable = False
    base_model_out = base_model.output
    base_model_out = layers.Reshape((-1, base_model_out.shape[-1]))(base_model_out)
    cnn_model = keras.models.Model(base_model.input, base_model_out)
    return cnn_model

# %%
class TransformerEncoderBlock(layers.Layer):
    def __init__(self, embed_dim, dense_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.dense_dim = dense_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.0
        )
        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.dense_1 = layers.Dense(embed_dim, activation="relu")

    def call(self, inputs, training, mask=None):
        inputs = self.layernorm_1(inputs)
        inputs = self.dense_1(inputs)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=None,
            training=training,
        )
        out_1 = self.layernorm_2(inputs + attention_output_1)
        return out_1

# %%
class PositionalEmbedding(layers.Layer):
    def __init__(self, sequence_length, vocab_size, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.token_embeddings = layers.Embedding(
            input_dim=vocab_size, output_dim=embed_dim
        )
        self.position_embeddings = layers.Embedding(
            input_dim=sequence_length, output_dim=embed_dim
        )
        self.sequence_length = sequence_length
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.embed_scale = tf.math.sqrt(tf.cast(embed_dim, tf.float32))

    def call(self, inputs):
        length = tf.shape(inputs)[-1]
        positions = tf.range(start=0, limit=length, delta=1)
        embedded_tokens = self.token_embeddings(inputs)
        embedded_tokens = embedded_tokens * self.embed_scale
        embedded_positions = self.position_embeddings(positions)
        return embedded_tokens + embedded_positions

    def compute_mask(self, inputs, mask=None):
        return tf.math.not_equal(inputs, 0)

# %%
class TransformerDecoderBlock(layers.Layer):
    def __init__(self, embed_dim, ff_dim, num_heads, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim
        self.ff_dim = ff_dim
        self.num_heads = num_heads
        self.attention_1 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.attention_2 = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim, dropout=0.1
        )
        self.ffn_layer_1 = layers.Dense(ff_dim, activation="relu")
        self.ffn_layer_2 = layers.Dense(embed_dim)

        self.layernorm_1 = layers.LayerNormalization()
        self.layernorm_2 = layers.LayerNormalization()
        self.layernorm_3 = layers.LayerNormalization()

        self.embedding = PositionalEmbedding(
            embed_dim=EMBED_DIM, sequence_length=SEQ_LENGTH, vocab_size=VOCAB_SIZE
        )
        self.out = layers.Dense(VOCAB_SIZE, activation="softmax")

        self.dropout_1 = layers.Dropout(0.3)
        self.dropout_2 = layers.Dropout(0.5)
        self.supports_masking = True

    def call(self, inputs, encoder_outputs, training, mask=None):
        inputs = self.embedding(inputs)
        causal_mask = self.get_causal_attention_mask(inputs)

        if mask is not None:
            padding_mask = tf.cast(mask[:, :, tf.newaxis], dtype=tf.int32)
            combined_mask = tf.cast(mask[:, tf.newaxis, :], dtype=tf.int32)
            combined_mask = tf.minimum(combined_mask, causal_mask)

        attention_output_1 = self.attention_1(
            query=inputs,
            value=inputs,
            key=inputs,
            attention_mask=combined_mask,
            training=training,
        )
        out_1 = self.layernorm_1(inputs + attention_output_1)

        attention_output_2 = self.attention_2(
            query=out_1,
            value=encoder_outputs,
            key=encoder_outputs,
            attention_mask=padding_mask,
            training=training,
        )
        out_2 = self.layernorm_2(out_1 + attention_output_2)

        ffn_out = self.ffn_layer_1(out_2)
        ffn_out = self.dropout_1(ffn_out, training=training)
        ffn_out = self.ffn_layer_2(ffn_out)

        ffn_out = self.layernorm_3(ffn_out + out_2, training=training)
        ffn_out = self.dropout_2(ffn_out, training=training)
        preds = self.out(ffn_out)
        return preds

    def get_causal_attention_mask(self, inputs):
        input_shape = tf.shape(inputs)
        batch_size, sequence_length = input_shape[0], input_shape[1]
        i = tf.range(sequence_length)[:, tf.newaxis]
        j = tf.range(sequence_length)
        mask = tf.cast(i >= j, dtype="int32")
        mask = tf.reshape(mask, (1, input_shape[1], input_shape[1]))
        mult = tf.concat(
            [tf.expand_dims(batch_size, -1), tf.constant([1, 1], dtype=tf.int32)],
            axis=0,
        )
        return tf.tile(mask, mult)

# %%
class ImageCaptioningModel(keras.Model):
    def __init__(
        self, cnn_model, encoder, decoder, num_captions_per_image=5, image_aug=None,
    ):
        super().__init__()
        self.cnn_model = cnn_model
        self.encoder = encoder
        self.decoder = decoder
        self.loss_tracker = keras.metrics.Mean(name="loss")
        self.acc_tracker = keras.metrics.Mean(name="accuracy")
        self.num_captions_per_image = num_captions_per_image
        self.image_aug = image_aug

    def calculate_loss(self, y_true, y_pred, mask):
        loss = self.loss(y_true, y_pred)
        mask = tf.cast(mask, dtype=loss.dtype)
        loss *= mask
        return tf.reduce_sum(loss) / tf.reduce_sum(mask)

    def calculate_accuracy(self, y_true, y_pred, mask):
        accuracy = tf.equal(y_true, tf.argmax(y_pred, axis=2))
        accuracy = tf.math.logical_and(mask, accuracy)
        accuracy = tf.cast(accuracy, dtype=tf.float32)
        mask = tf.cast(mask, dtype=tf.float32)
        return tf.reduce_sum(accuracy) / tf.reduce_sum(mask)

    def _compute_caption_loss_and_acc(self, img_embed, batch_seq, training=True):
        encoder_out = self.encoder(img_embed, training=training)
        batch_seq_inp = batch_seq[:, :-1]
        batch_seq_true = batch_seq[:, 1:]
        mask = tf.math.not_equal(batch_seq_true, 0)
        batch_seq_pred = self.decoder(
            batch_seq_inp, encoder_out, training=training, mask=mask
        )
        loss = self.calculate_loss(batch_seq_true, batch_seq_pred, mask)
        acc = self.calculate_accuracy(batch_seq_true, batch_seq_pred, mask)
        return loss, acc

    def train_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        if self.image_aug:
            batch_img = self.image_aug(batch_img)

        img_embed = self.cnn_model(batch_img)

        for i in range(self.num_captions_per_image):
            with tf.GradientTape() as tape:
                loss, acc = self._compute_caption_loss_and_acc(
                    img_embed, batch_seq[:, i, :], training=True
                )

                batch_loss += loss
                batch_acc += acc

            train_vars = (
                self.encoder.trainable_variables + self.decoder.trainable_variables
            )

            grads = tape.gradient(loss, train_vars)


            self.optimizer.apply_gradients(zip(grads, train_vars))


        batch_acc /= float(self.num_captions_per_image)
        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)

        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    def test_step(self, batch_data):
        batch_img, batch_seq = batch_data
        batch_loss = 0
        batch_acc = 0

        img_embed = self.cnn_model(batch_img)


        for i in range(self.num_captions_per_image):
            loss, acc = self._compute_caption_loss_and_acc(
                img_embed, batch_seq[:, i, :], training=False
            )

            batch_loss += loss
            batch_acc += acc

        batch_acc /= float(self.num_captions_per_image)


        self.loss_tracker.update_state(batch_loss)
        self.acc_tracker.update_state(batch_acc)


        return {"loss": self.loss_tracker.result(), "acc": self.acc_tracker.result()}

    @property
    def metrics(self):
        return [self.loss_tracker, self.acc_tracker]

# %%
cnn_model = get_cnn_model()
encoder = TransformerEncoderBlock(embed_dim=EMBED_DIM, dense_dim=FF_DIM, num_heads=1)
decoder = TransformerDecoderBlock(embed_dim=EMBED_DIM, ff_dim=FF_DIM, num_heads=2)
caption_model = ImageCaptioningModel(
    cnn_model=cnn_model, encoder=encoder, decoder=decoder, image_aug=image_augmentation,
)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 [==============================] - 0s 0us/step

# %%
# Define the loss function
cross_entropy = keras.losses.SparseCategoricalCrossentropy(
    from_logits=False, reduction="none"
)

# EarlyStopping criteria
early_stopping = keras.callbacks.EarlyStopping(patience=3, restore_best_weights=True)


# Learning Rate Scheduler for the optimizer
class LRSchedule(keras.optimizers.schedules.LearningRateSchedule):
    def __init__(self, post_warmup_learning_rate, warmup_steps):
        super().__init__()
        self.post_warmup_learning_rate = post_warmup_learning_rate
        self.warmup_steps = warmup_steps

    def __call__(self, step):
        global_step = tf.cast(step, tf.float32)
        warmup_steps = tf.cast(self.warmup_steps, tf.float32)
        warmup_progress = global_step / warmup_steps
        warmup_learning_rate = self.post_warmup_learning_rate * warmup_progress
        return tf.cond(
            global_step < warmup_steps,
            lambda: warmup_learning_rate,
            lambda: self.post_warmup_learning_rate,
        )


# Create a learning rate schedule
num_train_steps = len(train_dataset) * EPOCHS
num_warmup_steps = num_train_steps // 15
lr_schedule = LRSchedule(post_warmup_learning_rate=1e-4, warmup_steps=num_warmup_steps)

# Compile the model
caption_model.compile(optimizer=keras.optimizers.SGD(learning_rate=0.1), loss=cross_entropy)

# Fit the model
caption_model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=valid_dataset,
    callbacks=[early_stopping],
)
# Out:
# Epoch 1/30
# 215/215 [==============================] - 213s 884ms/step - loss: 21.7195 - acc: 0.2545 - val_loss: 19.1438 - val_acc: 0.2931
# Epoch 2/30
# 215/215 [==============================] - 59s 275ms/step - loss: 18.3999 - acc: 0.3215 - val_loss: 17.6653 - val_acc: 0.3423
# Epoch 3/30
# 215/215 [==============================] - 58s 268ms/step - loss: 17.2568 - acc: 0.3433 - val_loss: 17.1094 - val_acc: 0.3168
# Epoch 4/30
# 215/215 [==============================] - 57s 266ms/step - loss: 16.4924 - acc: 0.3569 - val_loss: 16.6174 - val_acc: 0.3225
# Epoch 5/30
# 215/215 [==============================] - 59s 273ms/step - loss: 15.9198 - acc: 0.3690 - val_loss: 16.2394 - val_acc: 0.3321
# Epoch 6/30
# 215/215 [==============================] - 58s 271ms/step - loss: 15.4480 - acc: 0.3778 - val_loss: 15.9822 - val_acc: 0.3509
# Epoch 7/30
# 215/215 [==============================] - 57s 265ms/step - loss: 15.0516 - acc: 0.3871 - val_loss: 15.6668 - val_acc: 0.3792
# Epoch 8/30
# 215/215 [==============================] - 59s 272ms/step - loss: 14.6893 - acc: 0.3939 - val_loss: 15.5999 - val_acc: 0.3757
# Epoch 9/30
# 215/215 [==============================] - 57s 266ms/step - loss: 14.3810 - acc: 0.4010 - val_loss: 15.5075 - val_acc: 0.3783
# Epoch 10/30
# 215/215 [==============================] - 58s 270ms/step - loss: 14.0914 - acc: 0.4092 - val_loss: 15.3890 - val_acc: 0.3807
# Epoch 11/30
# 215/215 [==============================] - 57s 266ms/step - loss: 13.8051 - acc: 0.4158 - val_loss: 15.2114 - val_acc: 0.3901
# Epoch 12/30
# 215/215 [==============================] - 58s 270ms/step - loss: 13.5662 - acc: 0.4210 - val_loss: 15.2699 - val_acc: 0.3839
# Epoch 13/30
# 215/215 [==============================] - 57s 265ms/step - loss: 13.3374 - acc: 0.4271 - val_loss: 15.3531 - val_acc: 0.3582
# Epoch 14/30
# 215/215 [==============================] - 57s 265ms/step - loss: 13.1165 - acc: 0.4312 - val_loss: 15.0180 - val_acc: 0.3956
# Epoch 15/30
# 215/215 [==============================] - 58s 271ms/step - loss: 12.8895 - acc: 0.4360 - val_loss: 14.9999 - val_acc: 0.3993
# Epoch 16/30
# 215/215 [==============================] - 57s 266ms/step - loss: 12.6931 - acc: 0.4424 - val_loss: 14.9887 - val_acc: 0.4015
# Epoch 17/30
# 215/215 [==============================] - 58s 269ms/step - loss: 12.4887 - acc: 0.4476 - val_loss: 14.9852 - val_acc: 0.4017
# Epoch 18/30
# 215/215 [==============================] - 58s 271ms/step - loss: 12.3059 - acc: 0.4514 - val_loss: 15.0444 - val_acc: 0.4000
# Epoch 19/30
# 215/215 [==============================] - 58s 271ms/step - loss: 12.1314 - acc: 0.4555 - val_loss: 15.0243 - val_acc: 0.3993
# Epoch 20/30
# 215/215 [==============================] - 59s 271ms/step - loss: 11.9667 - acc: 0.4607 - val_loss: 14.9462 - val_acc: 0.4066
# Epoch 21/30
# 215/215 [==============================] - 58s 267ms/step - loss: 11.8009 - acc: 0.4661 - val_loss: 15.0550 - val_acc: 0.3992
# Epoch 22/30
# 215/215 [==============================] - 57s 264ms/step - loss: 11.6539 - acc: 0.4681 - val_loss: 15.0662 - val_acc: 0.4044
# Epoch 23/30
# 215/215 [==============================] - 58s 270ms/step - loss: 11.4888 - acc: 0.4733 - val_loss: 15.1151 - val_acc: 0.3971

# %%
caption_model.save_weights('model.h5')

# %%
vocab = vectorization.get_vocabulary()
index_lookup = dict(zip(range(len(vocab)), vocab))
max_decoded_sentence_length = SEQ_LENGTH - 1
valid_images = list(valid_data.keys())


def generate_caption():
    # Select a random image from the validation dataset
    sample_img = np.random.choice(valid_images)

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == " <end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)

# %%
# Check predictions for a few samples
generate_caption()
generate_caption()
# Out:
# Predicted Caption:  a woman wearing a hat and hat is looking at the window
# Predicted Caption:  a young boy wearing a white shirt and blue shorts is holding a white and blue cup up a white hat his

# %% [markdown]
# ##Testing on real data

# %%
def generate_caption_test(image_path):
    # Select a random image from the validation dataset
    sample_img = image_path

    # Read the image from the disk
    sample_img = decode_and_resize(sample_img)
    img = sample_img.numpy().clip(0, 255).astype(np.uint8)
    plt.imshow(img)
    plt.show()

    # Pass the image to the CNN
    img = tf.expand_dims(sample_img, 0)
    img = caption_model.cnn_model(img)

    # Pass the image features to the Transformer encoder
    encoded_img = caption_model.encoder(img, training=False)

    # Generate the caption using the Transformer decoder
    decoded_caption = "<start> "
    for i in range(max_decoded_sentence_length):
        tokenized_caption = vectorization([decoded_caption])[:, :-1]
        mask = tf.math.not_equal(tokenized_caption, 0)
        predictions = caption_model.decoder(
            tokenized_caption, encoded_img, training=False, mask=mask
        )
        sampled_token_index = np.argmax(predictions[0, i, :])
        sampled_token = index_lookup[sampled_token_index]
        if sampled_token == " <end>":
            break
        decoded_caption += " " + sampled_token

    decoded_caption = decoded_caption.replace("<start> ", "")
    decoded_caption = decoded_caption.replace(" <end>", "").strip()
    print("Predicted Caption: ", decoded_caption)

# %%
generate_caption_test('/content/drive/MyDrive/friends-walking-on-pathway-amidst-trees-in-forest-CAVF00041.jpg')
# Out:
# Predicted Caption:  three people are walking on a dirt path in a forest

# %%
generate_caption_test('/content/drive/MyDrive/2023_06_27_16_01_IMG_5087-final.JPG')
# Out:
# Predicted Caption:  a man wearing a black shirt and sunglasses standing on a fence a fence

# %%
generate_caption_test('/content/drive/MyDrive/190515-xprize.png')
# Out:
# Predicted Caption:  a group of people are standing in front of a group of people
